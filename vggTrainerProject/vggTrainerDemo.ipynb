# %%
from vgg16Trainer import VGGTrainer

# %%
import os

# %%
dir_path = "/Users/kennethzhang/Desktop/cell_images"

trainer = VGGTrainer(dir_path, epochs = 10, color_mode = 'rgb',
            class_mode = 'categorical', target_image_size = (130, 130))

# %%
trainer.visualize_dimDistr(dir_name = "test", class_name = "parasitized")
# Out:
# /Users/kennethzhang/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
trainer.create_generators()
# Out:
# Found 24958 images belonging to 2 classes.
# Found 2600 images belonging to 2 classes.
# (<keras.preprocessing.image.DirectoryIterator at 0x2ba9a2e50>,
#  <keras.preprocessing.image.DirectoryIterator at 0x2ba9a2d90>)

# %%
trainer.build_vgg()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# 0. <CNNblockGenerator.BlockGenerator object at 0x2baa3c040>
# 1. <CNNblockGenerator.BlockGenerator object at 0x2baa4a790>
# 2. <CNNblockGenerator.BlockGenerator object at 0x2bc138070>
# 3. <CNNblockGenerator.BlockGenerator object at 0x2bc13e520>
# 4. <keras.layers.core.dense.Dense object at 0x2bc13e580>
# 5. <keras.layers.core.dense.Dense object at 0x2bc1380d0>
# 6. <keras.layers.core.dense.Dense object at 0x2bc143d30>
# 7. <keras.layers.core.dense.Dense object at 0x2bc143a30>
# 8. <keras.layers.core.dense.Dense object at 0x2bc158430>
# 2023-03-03 22:32:20.776405: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %%
trainer.fit_vgg()
# Out:
# Model not implemented, get input and outputs from Functional API.
# 2023-03-03 22:32:21.033779: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
